# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
cities = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))
world.plot();
cities.plot();

# %%
# Plot by GDP per capta
world = world[(world.pop_est>0) & (world.name!="Antarctica")]
world['gdp_per_cap'] =  world.pop_est/world.area #world.gdp_md_est /
world.plot(column='gdp_per_cap');

# %%
fp ="NHS_England_Regions/36b75cbf-240d-48b8-8a05-4cc39311f3d12020329-1-d6l3r.xvomui.shp"
gpd.read_file(fp)
map_dfnhs = gpd.read_file(fp)
# check data type so we can see that this is not a normal dataframe, but a GEOdataframe
map_dfnhs
# Out:
#    objectid  nhser19cd                 nhser19nm   bng_e   bng_n      long  \
# 0         1  E40000003                    London  517516  178392 -0.308640
# 1         2  E40000005                South East  471724  171073 -0.969570
# 2         3  E40000006                South West  285015  102567 -3.633430
# 3         4  E40000007           East of England  565965  255838  0.425775
# 4         5  E40000008                  Midlands  436686  314502 -1.458210
# 5         6  E40000009  North East and Yorkshire  418073  477340 -1.724520
# 6         7  E40000010                North West  360675  444637 -2.599910
#
#          lat    st_area(sh    st_length(  \
# 0  51.492271  1.573533e+09  4.199900e+05
# 1  51.434120  1.868954e+10  2.402430e+06
# 2  50.811192  2.388125e+10  3.399198e+06
# 3  52.175850  1.978900e+10  2.697755e+06
# 4  52.726940  2.759753e+10  1.772596e+06
# 5  54.191521  2.954411e+10  2.455125e+06
# 6  53.896412  9.385441e+09  1.621985e+06
#
# ...

# %%
#fig = plt.figure()
#ax = plt.subplot(111)
map_dfnhs['number']=[1,2,3,4,5,6,7]
map_dfnhs.plot(column='number')
plt.axis('off')
# Out:
# (54023.3637749996, 684293.4377250004, -27271.9100499996, 690143.9110499998)

# %%
fp ="London-wards-2018/London-wards-2018_ESRI/London_Ward_CityMerged.shp"
gpd.read_file(fp)
map_df = gpd.read_file(fp)
# check data type so we can see that this is not a normal dataframe, but a GEOdataframe
map_df.head()
# Out:
#                      NAME   GSS_CODE              DISTRICT  LAGSSCODE  \
# 0       Chessington South  E05000405  Kingston upon Thames  E09000021
# 1  Tolworth and Hook Rise  E05000414  Kingston upon Thames  E09000021
# 2              Berrylands  E05000401  Kingston upon Thames  E09000021
# 3               Alexandra  E05000400  Kingston upon Thames  E09000021
# 4                Beverley  E05000402  Kingston upon Thames  E09000021
#
#    HECTARES  NONLD_AREA                                           geometry
# 0   755.173         0.0  POLYGON ((516401.596 160201.802, 516407.302 16...
# 1   259.464         0.0  POLYGON ((519552.998 164295.600, 519508.096 16...
# 2   145.390         0.0  POLYGON ((518107.499 167303.399, 518114.301 16...
# 3   268.506         0.0  POLYGON ((520336.700 165105.498, 520332.198 16...
# 4   187.821         0.0  POLYGON ((521201.203 169275.505, 521204.303 16...

# %%
map_df.plot()
plt.axis('off')
# Out:
# (500648.73475333815, 564876.9609795979, 153596.64224543425, 203188.0578653461)

# %%
fp="Local/7ec4cb65-abbe-430f-8836-2b3dcebf2c67202043-1-1lsvg2e.obmj.shp"
acode="lad17cd"

#fp="LocalAuthority/d7409bf5-7f4b-4021-9879-6d0019eb2c442020329-1-mf1ytr.p0rya.shp"
#acode="LAD19CD"

#fp="Authority/ef8b12e3-643b-4e47-af16-72a55a5579db202041-1-6755x0.jqu5g.shp"
#acode="cauth19cd"

#https://geoportal.statistics.gov.uk/datasets/counties-and-unitary-authorities-april-2019-boundaries-ew-bgc/data
fp="CountiesUnit/a9ff8ed7-bff0-4539-9232-b76c42902b09202043-1-1rp6vl7.bq3t.shp"
acode="ctyua19cd"

map_df = gpd.read_file(fp)
# check data type so we can see that this is not a normal dataframe, but a GEOdataframe
#map_df

# %%
map_df.plot()
plt.axis('off')
# Out:
# (54024.091005000286, 684293.4030950004, -27258.996475000124, 690146.8635750005)

# %%
dir="http://www.damtp.cam.ac.uk/user/tb561/Corona/"
dir="../../Covid19/CoronaUK/"

ukagetab=pd.read_excel(dir+"ukmidyearestimates20182019ladcodes.xls",sheet_name="MYE 5",header=4,usecols="A:F",nrows=431)

# %%
print("E",map_df[acode][map_df[acode].astype(str).str[0]=="E"].size)
print("K",map_df[acode][map_df[acode].astype(str).str[0]=="K"].size)
print("N",map_df[acode][map_df[acode].astype(str).str[0]=="N"].size)
print("S",map_df[acode][map_df[acode].astype(str).str[0]=="S"].size)
print("W",map_df[acode][map_df[acode].astype(str).str[0]=="W"].size)
print(map_df[acode].size)
# Out:
# ('E', 151)
# ('K', 0)
# ('N', 0)
# ('S', 0)
# ('W', 22)
# 173

# %%
print("E",ukagetab["Code"][ukagetab["Code"].astype(str).str[0]=="E"].size)
print("K",ukagetab["Code"][ukagetab["Code"].astype(str).str[0]=="K"].size)
print("N",ukagetab["Code"][ukagetab["Code"].astype(str).str[0]=="N"].size)
print("S",ukagetab["Code"][ukagetab["Code"].astype(str).str[0]=="S"].size)
print("W",ukagetab["Code"][ukagetab["Code"].astype(str).str[0]=="W"].size)
print(ukagetab["Code"].size)
# Out:
# ('E', 359)
# ('K', 3)
# ('N', 12)
# ('S', 33)
# ('W', 23)
# 431

# %%
'''
for a in map_df[acode]:
    tmp=ukagetab[ukagetab["Code"]==a]["2018 people per sq. km"].to_numpy()
    #print(tmp)
    print(map_df[map_df[acode]==a].index)

'''
# Out:
# '\nfor a in map_df[acode]:\n    tmp=ukagetab[ukagetab["Code"]==a]["2018 people per sq. km"].to_numpy()\n    #print(tmp)\n    print(map_df[map_df[acode]==a].index)\n\n'

# %%
mrg=map_df.merge(ukagetab, left_on=[acode], right_on=['Code'], how='left')

# %%
mrg["2018 people per sq. km"]
# Out:
# 0       997.0
# 1      2608.0
# 2       558.0
# 3       962.0
# 4       540.0
# 5      1624.0
# 6      1160.0
# 7      1087.0
# 8      3997.0
# 9      3648.0
# 10      141.0
# 11      833.0
# 12      203.0
# 13      772.0
# 14     3296.0
# 15     4843.0
# 16      104.0
# 17     4437.0
# 18       88.0
# 19      612.0
#         ...
# 153     104.0
# 154     114.0
# 155     356.0
# 156     270.0
# 157      41.0
# 158      77.0
# 159      79.0
# 160     649.0
# 161     324.0
# 162     578.0
# 163     399.0
# 164    2585.0
# 165     566.0
# 166     653.0
# 167     641.0
# 168     740.0
# 169     111.0
# 170     805.0
# 171      26.0
# 172     540.0
# Name: 2018 people per sq. km, Length: 173, dtype: float64

# %%
fig=plt.figure(figsize=(20,20))
#ax=plt.subplot(111)
mrg.columns
#mrg.plot(column="Estimated Population mid-2018",cmap="Blues")
mrg["ldens"]=np.log10(mrg["2018 people per sq. km"])
mrg.plot(column="ldens", edgecolor='black',lw=1,figsize=(10,10),vmin=1.0,vmax=4.5)
plt.axis('equal')
plt.axis('off')


'''
sm = plt.cm.ScalarMappable(cmap=’Blues’, norm=plt.Normalize(vmin=vmin, vmax=vmax))
# empty array for the data range
sm._A = []
# add the colorbar to the figure
cbar = fig.colorbar(sm)

'''
plt.savefig('map.png',bbox_inches='tight')

# %%
w=mrg["2018 people per sq. km"].to_numpy()
min(np.log10(w))
max(np.log10(w))
# Out:
# 4.206744944053748

# %%
indatukloc=pd.read_csv(dir+"coronavirus-cases_latest.csv")
pd.set_option('display.max_rows', 40)
indatukloc
# Out:
#                      Area name  Area code                   Area type  \
# 0                      England  E92000001                      Nation
# 1                   South West  E12000009                      Region
# 2                   South East  E12000008                      Region
# 3                       London  E12000007                      Region
# 4              East of England  E12000006                      Region
# 5                West Midlands  E12000005                      Region
# 6                East Midlands  E12000004                      Region
# 7     Yorkshire and The Humber  E12000003                      Region
# 8                   North West  E12000002                      Region
# 9                   North East  E12000001                      Region
# 10              Worcestershire  E10000034  Upper tier local authority
# 11                 West Sussex  E10000032  Upper tier local authority
# ...

# %%
print("E",indatukloc["Area code"][indatukloc["Area code"].astype(str).str[0]=="E"].size)
print("K",indatukloc["Area code"][indatukloc["Area code"].astype(str).str[0]=="K"].size)
print("N",indatukloc["Area code"][indatukloc["Area code"].astype(str).str[0]=="N"].size)
print("S",indatukloc["Area code"][indatukloc["Area code"].astype(str).str[0]=="S"].size)
print("W",indatukloc["Area code"][indatukloc["Area code"].astype(str).str[0]=="W"].size)
print(indatukloc["Area code"].size)
# Out:
# ('E', 8538)
# ('K', 0)
# ('N', 0)
# ('S', 0)
# ('W', 0)
# 8538

# %%
date="2020-05-01"
indatukloc[indatukloc["Specimen date"]==date]
# Out:
#                        Area name  Area code                   Area type  \
# 160                      England  E92000001                      Nation
# 161                   South West  E12000009                      Region
# 162                   South East  E12000008                      Region
# 163                       London  E12000007                      Region
# 164              East of England  E12000006                      Region
# 165                West Midlands  E12000005                      Region
# 166                East Midlands  E12000004                      Region
# 167     Yorkshire and The Humber  E12000003                      Region
# 168                   North West  E12000002                      Region
# 169                   North East  E12000001                      Region
# 170                  West Sussex  E10000032  Upper tier local authority
# 171                       Surrey  E10000030  Upper tier local authority
# ...

# %%
map_dfnhs['nhser19nm']
# Out:
# 0                      London
# 1                  South East
# 2                  South West
# 3             East of England
# 4                    Midlands
# 5    North East and Yorkshire
# 6                  North West
# Name: nhser19nm, dtype: object

# %%
#mrg=map_df.merge(tmp, left_on=['LAD19NM'], right_on=['Area name'], how='left')
#mrg

# %%
#mrg["Cumulative lab-confirmed cases"]
#mrg2.columns
#mrg2["cpercap"]=mrg2["Cumulative lab-confirmed cases"]/(mrg2["Estimated Population mid-2018"]+1.0)*100.0

#mrg2["Estimated Population mid-2018"]
#mrg2["Cumulative lab-confirmed cases"]
#mrg2["cpercap"].max()
mrg2
# Out:
#      objectid  ctyua19cd                    ctyua19nm  \
# 0           1  E06000001                   Hartlepool
# 1           2  E06000002                Middlesbrough
# 2           3  E06000003         Redcar and Cleveland
# 3           4  E06000004             Stockton-on-Tees
# 4           5  E06000005                   Darlington
# 5           6  E06000006                       Halton
# 6           7  E06000007                   Warrington
# 7           8  E06000008        Blackburn with Darwen
# 8           9  E06000009                    Blackpool
# 9          10  E06000010  Kingston upon Hull, City of
# 10         11  E06000011     East Riding of Yorkshire
# 11         12  E06000012      North East Lincolnshire
# 12         13  E06000013           North Lincolnshire
# 13         14  E06000014                         York
# 14         15  E06000015                        Derby
# 15         16  E06000016                    Leicester
# ...

# %%
dates=["2020-03-16","2020-03-20","2020-03-24","2020-03-28","2020-04-01","2020-04-04","2020-04-08","2020-04-12","2020-04-16","2020-04-20","2020-04-24","2020-04-28","2020-05-02"]
dates=["2020-03-16"]
vmin=1
vmax=3000
for date in dates:
    fig, ax = plt.subplots(1, figsize=(20, 20))
    tmp=indatukloc[indatukloc["Specimen date"]==date]
    mrg=map_df.merge(tmp, left_on=[acode], right_on=['Area code'], how='left')
    mrg2=mrg.merge(ukagetab, left_on=[acode], right_on=['Code'], how='left')
    mrg2["cpercap"]=mrg2["Cumulative lab-confirmed cases"]/(mrg2["Estimated Population mid-2018"]+1.0)*100000.0
    mrg2=mrg2.fillna(value=1)
    #mrg2.plot(column="Cumulative lab-confirmed cases", edgecolor='black',lw=1,figsize=(20,20),vmin=vmin,vmax=vmax,cmap='Reds')#
    vmin=0.0
    vmax=500.0
    mrg3=mrg2[mrg2["Area code"].astype(str).str[0]=="E"]
    mrg3.plot(column="cpercap", edgecolor='black',lw=1,vmin=vmin,vmax=vmax,cmap='Reds',ax=ax)#,figsize=(20,20)
    sm = plt.cm.ScalarMappable(cmap='Reds', norm=plt.Normalize(vmin=vmin, vmax=vmax))
    # empty array for the data range
    sm._A = []
    # add the colorbar to the figure
    cbar = plt.colorbar(sm)
    plt.annotate(date,xy=(0.1,0.9),  xycoords='figure fraction', horizontalalignment='left', verticalalignment='top', fontsize=24, color='k')
    ax.set_xticks([])
    ax.set_yticks([])
    plt.savefig('map'+date+'.png',bbox_inches='tight');
